.0], [111.0], [91.0], [105.0], [103.0], [102.0], [93.0], [91.0], [105.0], [106.0], [96.0], [91.0], [108.0], [100.0], [94.0], [94.0], [113.0], [97.0], [103.0], [101.0], [115.0], [85.0], [90.0], [118.0], [91.0], [96.0], [115.0], [94.0], [106.0], [118.0], [102.0], [107.0], [86.0], [102.0], [86.0], [103.0], [107.0], [116.0], [94.0], [112.0], [87.0], [123.0], [104.0], [125.0], [102.0], [99.0], [87.0], [106.0], [94.0]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
result = soup.find_all('td', class_ = 'align-left fixed', attrs={"data-col-id": 'Name'})
df = pd.DataFrame()
df['name'] = result
df['name'] = df['name'].apply(lambda x: x.text)

result = soup.find_all('td', class_ = 'align-right', attrs={"data-col-id": 'OBP+'})
df['OBP+'] = result
df['OBP+'] = df['OBP+'].apply(lambda x: float(x.text))

result = soup.find_all('td', class_ = 'align-right', attrs={"data-col-id": 'SLG+'})
df['SLG+'] = result
df['SLG+'] = df['SLG+'].apply(lambda x: float(x.text))

result = soup.find_all('td', class_ = 'align-right', attrs={"data-col-id": 'wRC+'})
df['wRC+'] = result
df['wRC+'] = df['wRC+'].apply(lambda x: float(x.text))
show(df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_53b3a27a_1706_45ee_b268_ada7666b7290"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_53b3a27a_1706_45ee_b268_ada7666b7290:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>name</th>\n      <th>OBP+</th>\n      <th>SLG+</th>\n      <th>wRC+</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Zach McKinstry\", 106.0, 108.0, 114.0], [\"Steven Kwan\", 106.0, 92.0, 99.0], [\"Luis Arraez\", 103.0, 97.0, 104.0], [\"Lenyn Sosa\", 94.0, 107.0, 100.0], [\"J.P. Crawford\", 112.0, 91.0, 113.0], [\"Bryan Reynolds\", 100.0, 100.0, 99.0], [\"Xavier Edwards\", 108.0, 88.0, 95.0], [\"Luis Rengifo\", 92.0, 83.0, 73.0], [\"Zach Neto\", 102.0, 117.0, 116.0], [\"Gavin Lux\", 110.0, 93.0, 102.0], [\"James Wood\", 110.0, 118.0, 127.0], [\"Brandon Lowe\", 98.0, 118.0, 114.0], [\"Carlos Correa\", 106.0, 99.0, 106.0], [\"Ernie Clement\", 100.0, 98.0, 98.0], [\"Nolan Schanuel\", 113.0, 96.0, 109.0], [\"Mike Trout\", 115.0, 108.0, 120.0], [\"Geraldo Perdomo\", 123.0, 115.0, 138.0], [\"Paul Goldschmidt\", 105.0, 99.0, 103.0], [\"Bo Bichette\", 114.0, 119.0, 134.0], [\"Brent Rooker\", 107.0, 118.0, 122.0], [\"Freddie Freeman\", 116.0, 125.0, 139.0], [\"Nick Castellanos\", 93.0, 100.0, 90.0], [\"Dansby Swanson\", 94.0, 104.0, 99.0], [\"Andy Pages\", 99.0, 115.0, 113.0], [\"Kyle Manzardo\", 100.0, 112.0, 113.0], [\"Josh Jung\", 94.0, 96.0, 91.0], [\"Ian Happ\", 108.0, 104.0, 116.0], [\"George Springer\", 127.0, 138.0, 166.0], [\"Brice Turang\", 113.0, 108.0, 124.0], [\"Francisco Lindor\", 109.0, 116.0, 129.0], [\"Wyatt Langford\", 110.0, 106.0, 118.0], [\"Michael Busch\", 108.0, 130.0, 140.0], [\"TJ Friedl\", 115.0, 94.0, 109.0], [\"Seiya Suzuki\", 103.0, 119.0, 123.0], [\"Vladimir Guerrero Jr.\", 122.0, 115.0, 137.0], [\"Alec Bohm\", 104.0, 102.0, 105.0], [\"Lawrence Butler\", 98.0, 100.0, 96.0], [\"Gleyber Torres\", 114.0, 95.0, 113.0], [\"Ryan O'Hearn\", 116.0, 108.0, 127.0], [\"Masyn Winn\", 98.0, 90.0, 91.0], [\"J.T. Realmuto\", 99.0, 96.0, 94.0], [\"Xander Bogaerts\", 104.0, 97.0, 104.0], [\"Kyle Tucker\", 119.0, 115.0, 136.0], [\"Gunnar Henderson\", 111.0, 108.0, 120.0], [\"Mookie Betts\", 103.0, 101.0, 104.0], [\"Gavin Sheets\", 100.0, 107.0, 111.0], [\"Spencer Torkelson\", 106.0, 113.0, 118.0], [\"Andrew McCutchen\", 105.0, 91.0, 95.0], [\"Willy Adames\", 100.0, 105.0, 108.0], [\"Brendan Donovan\", 111.0, 105.0, 119.0], [\"Riley Greene\", 100.0, 122.0, 121.0], [\"Willson Contreras\", 108.0, 111.0, 124.0], [\"Jos\\u00e9 Ram\\u00edrez\", 115.0, 124.0, 133.0], [\"Marcus Semien\", 97.0, 90.0, 89.0], [\"Bobby Witt Jr.\", 112.0, 123.0, 130.0], [\"Josh Smith\", 107.0, 90.0, 100.0], [\"Matt Olson\", 115.0, 120.0, 136.0], [\"Jordan Beck\", 100.0, 103.0, 90.0], [\"Eric Wagaman\", 93.0, 94.0, 85.0], [\"Cody Bellinger\", 107.0, 118.0, 125.0], [\"Nico Hoerner\", 109.0, 98.0, 109.0], [\"Tyler Soderstrom\", 111.0, 117.0, 125.0], [\"Mike Yastrzemski\", 105.0, 100.0, 106.0], [\"Sal Frelick\", 111.0, 101.0, 114.0], [\"Spencer Steer\", 98.0, 102.0, 97.0], [\"Pete Alonso\", 109.0, 130.0, 141.0], [\"Jacob Wilson\", 113.0, 110.0, 121.0], [\"Trevor Larnach\", 103.0, 100.0, 102.0], [\"Chase Meidroth\", 105.0, 79.0, 87.0], [\"Nathaniel Lowe\", 97.0, 95.0, 91.0], [\"Aaron Judge\", 146.0, 170.0, 204.0], [\"Shea Langeliers\", 104.0, 132.0, 132.0], [\"Jake Cronenworth\", 116.0, 94.0, 117.0], [\"Corbin Carroll\", 108.0, 134.0, 139.0], [\"William Contreras\", 112.0, 99.0, 113.0], [\"CJ Abrams\", 99.0, 108.0, 107.0], [\"Trent Grisham\", 111.0, 114.0, 129.0], [\"Ozzie Albies\", 96.0, 91.0, 87.0], [\"Jarren Duran\", 106.0, 109.0, 111.0], [\"Ben Rice\", 108.0, 123.0, 133.0], [\"Christian Walker\", 95.0, 104.0, 99.0], [\"Jung Hoo Lee\", 103.0, 101.0, 107.0], [\"Marcell Ozuna\", 112.0, 100.0, 114.0], [\"Salvador Perez\", 91.0, 110.0, 95.0], [\"Maikel Garcia\", ...

# %%
df.to_csv('plusstats.csv', index = False)
