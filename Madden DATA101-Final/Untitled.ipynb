# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
DF = pd.read_csv('output.csv')
DF
# Out:
#        index            Player Team Pos  Age    G   AB    R    H  2B  ...  SH  \
# 0          0   Julio Rodriguez  SEA  OF   24  160  652  106  174  31  ...   0
# 1          1  Francisco Lindor  NYM  SS   32  160  644  117  172  35  ...   0
# 2          2   Elly De La Cruz  CIN  SS   23  162  629  102  166  31  ...   0
# 3          3      Brent Rooker  ATH  OF   31  162  626   92  164  40  ...   0
# 4          4       Steven Kwan  CLE  OF   28  156  625   81  170  29  ...   3
# ...      ...               ...  ...  ..  ...  ...  ...  ...  ...  ..  ...  ..
# 11085    666       Juan Castro  LAD  SS   53    1    3    0    0   0  ...   0
# 11086    667    Brian Esposito  HOU   C   46    2    3    0    0   0  ...   0
# 11087    668        Steve Hill  STL   C   40    1    3    1    1   0  ...   0
# 11088    669       Terry Evans  LAA  OF   43    1    1    0    0   0  ...   0
# 11089    670       J.C. Boscan  ATL   C   45    1    0    1    0   0  ...   0
#
#        SF  HBP    AVG    OBP    SLG    OPS  Year  League  adj_age
# 0       2   12  0.267  0.324  0.474  0.798  2025      AL       24
# 1       7   16  0.267  0.346  0.466  0.812  2025      NL       32
# 2       1    2  0.264  0.336  0.440  0.776  2025      NL       23
# 3       2    5  0.262  0.335  0.479  0.814  2025      AL       31
# 4       7    3  0.272  0.330  0.374  0.704  2025      AL       28
# ...    ..  ...    ...    ...    ...    ...   ...     ...      ...
# 11085   0    0  0.000  0.250  0.000  0.250  2010      NL       38
# 11086   0    0  0.000  0.000  0.000  0.000  2010      AL       31
# 11087   0    0  0.333  0.333  1.333  1.666  2010      NL       25
# 11088   0    0  0.000  0.000  0.000  0.000  2010      AL       28
# 11089   0    0  0.000  1.000  0.000  1.000  2010      NL       30
#
# [11090 rows x 27 columns]

# %%
fig = px.scatter(DF,x='Age',y='AVG')

fig.update_layout(
                  title='Age vs Batting Average of MLB Players',
                  xaxis_title="Age",
                  yaxis_title="Batting Average",
                  autosize=False,
                  width=800,
                  height=500)

fig.show()

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
ls
# Out:
# README.md               output.csv              sprint_speed(2025).csv
# Untitled.ipynb          sprint_speed(2015).csv

# %%
df15 = pd.read_csv('./sprint_speed(2015).csv')
df25 = pd.read_csv('./sprint_speed(2025).csv')
df15.head()
# Out:
#   last_name, first_name  player_id  team_id team position  age  \
# 0         Buxton, Byron     621439      142  MIN       CF   24
# 1     Sierra, Magneuris     642423      146  MIA       CF   22
# 2          Quinn, Roman     596451      143  PHI       CF   25
# 3           Engel, Adam     641553      145  CWS       CF   26
# 4       Hamilton, Billy     571740      113  CIN       CF   27
#
#    competitive_runs  bolts  hp_to_1b  sprint_speed
# 0                35   20.0      3.98          30.5
# 1                64   42.0      3.91          30.2
# 2                58   29.0      3.88          30.1
# 3               181   96.0      4.08          30.1
# 4               205   93.0      3.94          30.1

# %%
df25.head()
# Out:
#   last_name, first_name  player_id  team_id team position  age  \
# 0          Turner, Trea     607208      143  PHI       SS   32
# 1      Scott II, Victor     687363      138  STL       CF   24
# 2       Witt Jr., Bobby     677951      118   KC       SS   25
# 3         Buxton, Byron     621439      142  MIN       CF   31
# 4           Hill, Derek     656537      145  CWS       CF   29
#
#    competitive_runs  bolts  hp_to_1b  sprint_speed
# 0               265  117.0      4.22          30.3
# 1               141   87.0      4.13          30.2
# 2               245  101.0      4.15          30.2
# 3               165   56.0      4.13          30.2
# 4                50   24.0      4.21          30.1

# %%
df15.keys()
# Out:
# Index(['last_name, first_name', 'player_id', 'team_id', 'team', 'position',
#        'age', 'competitive_runs', 'bolts', 'hp_to_1b', 'sprint_speed'],
#       dtype='object')

# %%
fig = px.scatter(
    df25,
    x="position",
    y="sprint_speed",
    color="age",
    hover_data=["last_name, first_name", "team"],
    title="  vs Position by Age (2025)"
)

fig.show()

# %%
df25.groupby('position')['sprint_speed'].mean()
# Out:
# position
# 1B    26.510345
# 2B    27.666197
# 3B    27.213889
# C     26.131325
# CF    28.701563
# DH    26.508163
# LF    27.848387
# RF    27.771642
# SS    27.860377
# Name: sprint_speed, dtype: float64

# %%
df25_avg_sprintspeed=df25.groupby('position')['sprint_speed'].mean()

# %%
df25_avg_sprintspeed
# Out:
# position
# 1B    26.510345
# 2B    27.666197
# 3B    27.213889
# C     26.131325
# CF    28.701563
# DH    26.508163
# LF    27.848387
# RF    27.771642
# SS    27.860377
# Name: sprint_speed, dtype: float64

# %%
fig = px.bar(
    df25_avg_sprintspeed,
    #color="age",
   # hover_data=["sprint_speed"],
    title="Average Sprint Speed vs Position (2025)"
)
fig.update_layout(
                  xaxis_title="Position",
                  yaxis_title="Average Sprint Speed")
fig.show()

# %%
fig = px.scatter(
    df25_avg_sprintspeed,
 
    title=" Average Sprint Speed vs Position (2025)"
)

fig.show()

# %%
fig = px.scatter(
    df25,
    x="age",
    y="sprint_speed",
    color="position",
    hover_data=["last_name, first_name", "team","position"],
    title=" Age vs Sprint Speed by Position (2025)"
)
fig.show()
